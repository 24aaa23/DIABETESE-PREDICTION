# %% [markdown]
# # Part A: Importing Libraries
# In this section, we import the necessary libraries required for data manipulation, model training, and evaluation.

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import svm
from sklearn.metrics import accuracy_score

# %% [markdown]
# LOADING THE DATA AND KNowing abouty the data

# %% [markdown]
# # Part B: Data Preparation
# In this part, we prepare the data by separating the features from the target variable, standardizing the features, and splitting the dataset into training and testing sets.

# %%
X=diabetes_dataset.drop(columns='Outcome',axis=1)
Y=diabetes_dataset['Outcome']
scaler=StandardScaler()
scaler.fit(X)
standard_scaler=scaler.transform(X);
X=standard_scaler
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=2)

# %% [markdown]
# # Part C: Model Training
# Here, we create and train an SVM classifier using the training data. We then make predictions on the test data and evaluate the model's accuracy.

# %%
classifier=svm.SVC(kernel='linear')
classifier.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear')

# %% [raw]
# prediction on test data

# %%
X_test_prediction=classifier.predict(X_test)
test_data_accuracy=accuracy_score(X_test_prediction,Y_test)
print(test_data_accuracy)
# Out:
# 0.7727272727272727

# %% [markdown]
# # Part D: Making Predictions with New Data
# In this section, we prepare new input data, standardize it using the previously fitted scaler, and use the trained model to make predictions on the new data.

# %%
input_data=(4,110,92,0,0,37.6,0.191,20)
inputdata=np.asarray(input_data)
inputdata_reshape=inputdata.reshape(1,-1)
std_data=scaler.transform(inputdata_reshape)
print(std_data)
std_data_pred=classifier.predict(std_data)
print(std_data_pred)
# Out:
# [[ 0.04601433 -0.34096773  1.18359575 -1.28821221 -0.69289057  0.71168975
#   -0.84827977 -1.12663719]]
# [0]
# C:\Users\AMAN KUMAR SINGH\anaconda3\anac\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# standardised the input data
